# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/DL_Project_1/Age-cGAN-trained.zip -d /content
# Out:
# Archive:  /content/drive/MyDrive/DL_Project_1/Age-cGAN-trained.zip
# replace /content/Age-cGAN-trained/GAN_1/D_0.pkl? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: /content/Age-cGAN-trained/GAN_1/D_0.pkl
#   inflating: /content/Age-cGAN-trained/GAN_1/D_1.pkl
#   inflating: /content/Age-cGAN-trained/GAN_1/D_10.pkl
#   inflating: /content/Age-cGAN-trained/GAN_1/D_11.pkl
#   inflating: /content/Age-cGAN-trained/GAN_1/D_12.pkl
#   inflating: /content/Age-cGAN-trained/GAN_1/D_13.pkl
#   inflating: /content/Age-cGAN-trained/GAN_1/D_14.pkl
#   inflating: /content/Age-cGAN-trained/GAN_1/D_15.pkl
#   inflating: /content/Age-cGAN-trained/GAN_1/D_16.pkl
#   inflating: /content/Age-cGAN-trained/GAN_1/D_17.pkl
#   inflating: /content/Age-cGAN-trained/GAN_1/D_18.pkl
#   inflating: /content/Age-cGAN-trained/GAN_1/D_19.pkl
#   inflating: /content/Age-cGAN-trained/GAN_1/D_2.pkl
#   inflating: /content/Age-cGAN-trained/GAN_1/D_20.pkl
#   inflating: /content/Age-cGAN-trained/GAN_1/D_21.pkl
# ...

# %%
import pickle

# %%
import glob

# %%
f = open('/content/Age-cGAN-trained/GAN_1/G_49.pkl', 'r')

# %%
f
# Out:
# <_io.TextIOWrapper name='/content/Age-cGAN-trained/GAN_1/G_49.pkl' mode='r' encoding='UTF-8'>

# %%
model = pickle.loads(f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-bcd5b121bad4> in <module>
# ----> 1 model = pickle.loads(f)
#
# TypeError: a bytes-like object is required, not '_io.TextIOWrapper'
